# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('IRIS.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
pd.isna(df).sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.max()
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# sepal_length            4.3
# sepal_width             2.0
# petal_length            1.0
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %%
df.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

## Plot the data
fig, ax = plt.subplots(figsize=(10,6))

## Customize the plot
scatter = ax.scatter(x=df["sepal_length"],
                   y=df["sepal_width"],
                   c=df["petal_length"])

## Add a legend
ax.set(title="IRIS",
       xlabel="sepal_length",
       ylabel="sepal_width")

## Add a horixontal line or meanline
ax.legend(*scatter.legend_elements(), title="petal_length")

## To change the format of line
ax.axhline(df["sepal_width"].mean(),
           linestyle="--")

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.boxplot([df["petal_length"], df["petal_width"],df["sepal_length"], df["sepal_width"]])
plt.show()

# %%
Q1 = df["sepal_length"].quantile(0.25)
Q2 = df["sepal_length"].quantile(0.50)
Q3 = df["sepal_length"].quantile(0.75)

IQR = Q3 - Q1

print("Q1: ", Q1)
print("Q2: ", Q2)
print("Q3: ", Q3)

print("IQR: ",IQR)
# Out:
# Q1:  5.1
# Q2:  5.8
# Q3:  6.4
# IQR:  1.3000000000000007

# %%
Q1 = df["petal_width"].quantile(0.25)
Q2 = df["petal_width"].quantile(0.50)
Q3 = df["petal_width"].quantile(0.75)

IQR = Q3 - Q1

print("Q1: ", Q1)
print("Q2: ", Q2)
print("Q3: ", Q3)

print("IQR: ",IQR)
# Out:
# Q1:  0.3
# Q2:  1.3
# Q3:  1.8
# IQR:  1.5

# %%
Q1 = df["petal_length"].quantile(0.25)
Q2 = df["petal_length"].quantile(0.50)
Q3 = df["petal_length"].quantile(0.75)

IQR = Q3 - Q1

print("Q1: ", Q1)
print("Q2: ", Q2)
print("Q3: ", Q3)

print("IQR: ",IQR)
# Out:
# Q1:  1.6
# Q2:  4.35
# Q3:  5.1
# IQR:  3.4999999999999996

# %%
Q1 = df["sepal_width"].quantile(0.25)
Q2 = df["sepal_width"].quantile(0.50)
Q3 = df["sepal_width"].quantile(0.75)

IQR = Q3 - Q1

print("Q1: ", Q1)
print("Q2: ", Q2)
print("Q3: ", Q3)

print("IQR: ",IQR)
# Out:
# Q1:  2.8
# Q2:  3.0
# Q3:  3.3
# IQR:  0.5

# %%
Q1 = df["sepal_width"].quantile(0.25)
print("First quartile (25th percentile): ", Q1)
ques = Q1 -0.5*1.5
print(ques)
# Out:
# First quartile (25th percentile):  2.8
# 2.05

# %%
Q3 = df["sepal_width"].quantile(0.75)
print("First quartile (75th percentile): ", Q3)
ques = Q3 +0.5*1.5
print(ques)
# Out:
# First quartile (75th percentile):  3.3
# 4.05

# %% [markdown]
# Effective Pandas
