# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns 
# %matplotlib inline

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df_train=pd.read_csv("train.csv")
df_train
# Out:
#           id Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0          0   F   0.550     0.430   0.150        0.7715          0.3285
# 1          1   F   0.630     0.490   0.145        1.1300          0.4580
# 2          2   I   0.160     0.110   0.025        0.0210          0.0055
# 3          3   M   0.595     0.475   0.150        0.9145          0.3755
# 4          4   I   0.555     0.425   0.130        0.7820          0.3695
# ...      ...  ..     ...       ...     ...           ...             ...
# 90610  90610   M   0.335     0.235   0.075        0.1585          0.0685
# 90611  90611   M   0.555     0.425   0.150        0.8790          0.3865
# 90612  90612   I   0.435     0.330   0.095        0.3215          0.1510
# 90613  90613   I   0.345     0.270   0.075        0.2000          0.0980
# 90614  90614   I   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight  Rings
# 0              0.1465        0.2400     11
# ...

# %%
df_train.shape
# Out:
# (90615, 10)

# %%
df_train.describe()
# Out:
#                  id        Length      Diameter        Height  Whole weight  \
# count  90615.000000  90615.000000  90615.000000  90615.000000  90615.000000
# mean   45307.000000      0.517098      0.401679      0.135464      0.789035
# std    26158.441658      0.118217      0.098026      0.038008      0.457671
# min        0.000000      0.075000      0.055000      0.000000      0.002000
# 25%    22653.500000      0.445000      0.345000      0.110000      0.419000
# 50%    45307.000000      0.545000      0.425000      0.140000      0.799500
# 75%    67960.500000      0.600000      0.470000      0.160000      1.067500
# max    90614.000000      0.815000      0.650000      1.130000      2.825500
#
#        Whole weight.1  Whole weight.2  Shell weight         Rings
# count    90615.000000    90615.000000  90615.000000  90615.000000
# mean         0.340778        0.169422      0.225898      9.696794
# std          0.204428        0.100909      0.130203      3.176221
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90615 entries, 0 to 90614
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              90615 non-null  int64
#  1   Sex             90615 non-null  object
#  2   Length          90615 non-null  float64
#  3   Diameter        90615 non-null  float64
#  4   Height          90615 non-null  float64
#  5   Whole weight    90615 non-null  float64
#  6   Whole weight.1  90615 non-null  float64
#  7   Whole weight.2  90615 non-null  float64
#  8   Shell weight    90615 non-null  float64
#  9   Rings           90615 non-null  int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 6.9+ MB

# %%
col_names_train = ['id', 'Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1','Whole weight.2','Shell weight','Rings']
for col in col_names_train:
    print(df_train[col].value_counts())
# Out:
# id
# 0        1
# 60352    1
# 60416    1
# 60415    1
# 60414    1
#         ..
# 30203    1
# 30202    1
# 30201    1
# 30200    1
# 90614    1
# Name: count, Length: 90615, dtype: int64
# Sex
# I    33093
# M    31027
# F    26495
# Name: count, dtype: int64
# Length
# 0.5750    3267
# 0.5800    2670
# 0.5700    2167
# 0.5500    2122
# 0.5950    1992
#           ...
# 0.5630       1
# 0.3470       1
# 0.4405       1
# 0.3540       1
# 0.4110       1
# Name: count, Length: 157, dtype: int64
# Diameter
# 0.4500    4182
# 0.4750    3307
# 0.4550    2715
# 0.4000    2667
# 0.4700    2441
#           ...
# 0.0750       1
# 0.0550       1
# 0.3755       1
# 0.6500       1
# 0.1130       1
# Name: count, Length: 126, dtype: int64
# Height
# 0.1500    5742
# 0.1400    5415
# 0.1550    5230
# 0.1450    5048
# 0.1350    4980
#           ...
# 0.1160       1
# 0.0090       1
# 0.1030       1
# 0.0830       1
# 0.0925       1
# Name: count, Length: 90, dtype: int64
# Whole weight
# ...

# %%
x = df_train.drop("Rings",axis=1)
y = df_train['Rings']

# %%
x
# Out:
#           id Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 0          0   F   0.550     0.430   0.150        0.7715          0.3285
# 1          1   F   0.630     0.490   0.145        1.1300          0.4580
# 2          2   I   0.160     0.110   0.025        0.0210          0.0055
# 3          3   M   0.595     0.475   0.150        0.9145          0.3755
# 4          4   I   0.555     0.425   0.130        0.7820          0.3695
# ...      ...  ..     ...       ...     ...           ...             ...
# 90610  90610   M   0.335     0.235   0.075        0.1585          0.0685
# 90611  90611   M   0.555     0.425   0.150        0.8790          0.3865
# 90612  90612   I   0.435     0.330   0.095        0.3215          0.1510
# 90613  90613   I   0.345     0.270   0.075        0.2000          0.0980
# 90614  90614   I   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight
# 0              0.1465        0.2400
# ...

# %%
y
# Out:
# 0        11
# 1        11
# 2         6
# 3        10
# 4         9
#          ..
# 90610     6
# 90611     9
# 90612     6
# 90613     6
# 90614     8
# Name: Rings, Length: 90615, dtype: int64

# %%
df_train['Sex'].value_counts()
# Out:
# Sex
# I    33093
# M    31027
# F    26495
# Name: count, dtype: int64

# %%
df_train.isnull().sum()
# Out:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Whole weight.1    0
# Whole weight.2    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,x_test.shape
# Out:
# ((72492, 9), (18123, 9))

# %%
import category_encoders as ce

# %%
encoder = ce.OrdinalEncoder(cols=['id', 'Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1','Whole weight.2','Shell weight'])
x_train = encoder.fit_transform(x_train)
x_test = encoder.transform(x_test)

# %%
x_train.head()
# Out:
#        id  Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 87045   1    1       1         1       1             1               1
# 45728   2    2       2         2       2             2               2
# 20812   3    3       3         3       3             3               3
# 43201   4    3       4         4       4             4               4
# 23336   5    1       5         5       5             5               5
#
#        Whole weight.2  Shell weight
# 87045               1             1
# 45728               2             2
# 20812               3             3
# 43201               4             4
# 23336               5             5

# %%
x_test.head()
# Out:
#         id  Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# 51331 -1.0    2    22.0       9.0    19.0         767.0            44.0
# 67142 -1.0    3    33.0      32.0    10.0         210.0           122.0
# 51843 -1.0    2    26.0       2.0    35.0        2516.0            33.0
# 64555 -1.0    1    95.0      84.0    24.0        1196.0           176.0
# 46833 -1.0    2    17.0      22.0     7.0         596.0           250.0
#
#        Whole weight.2  Shell weight
# 51331           472.0         101.0
# 67142           123.0          47.0
# 51843           646.0         132.0
# 64555           412.0          59.0
# 46833           125.0          41.0

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Instantiate the DecisionTreeRegressor with the appropriate criterion
clf_mse = DecisionTreeRegressor(criterion='mse', random_state=0)

# Print the classifier
print(clf_mse)

# Fit the model
clf_mse.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', random_state=0)
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[74], line 10
#       7 print(clf_mse)
#       9 # Fit the model
# ---> 10 clf_mse.fit(x_train, y_train)
#
# File c:\Python311\Lib\site-packages\sklearn\base.py:1467, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1462 partial_fit_and_fitted = (
#    1463     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1464 )
#    1466 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
#    1474     return fit_method(estimator, *args, **kwargs)
#
# ...
