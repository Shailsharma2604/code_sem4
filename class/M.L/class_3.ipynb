# %%
import pandas as pd

# %%
df=pd.read_csv("train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
numerical_columns=[i for i in df.columns if df[i].dtypes!='O']
categorical_columns=[i for i in df.columns if df[i].dtypes=='O']
print(numerical_columns)
print(categorical_columns)
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']
# ...

# %%
len(numerical_columns)
# Out:
# 38

# %%
len(categorical_columns)
# Out:
# 43

# %%
def null_values(x):
    column_with_null_Values={}
    for i in x:
        print(i)
        if(df[i].isna().sum()!=0):
            column_with_null_Values[1]=round((df[i].isna()/len(df))*100,2)
    return column_with_null_Values

# %%
numeric_null_percentage=null_values(numerical_columns)
# Out:
# Id
# MSSubClass
# LotFrontage
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageYrBlt
# GarageCars
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# MoSold
# YrSold
# SalePrice

# %%
for i in df.columns:
    count=0
    for j in df[i]:
        if(j==0):
            count+=1

    print("percenteage for null vals in",i,"is : ",(count/len(df[i]))*100)
# Out:
# percenteage for null vals in Id is :  0.0
# percenteage for null vals in MSSubClass is :  0.0
# percenteage for null vals in MSZoning is :  0.0
# percenteage for null vals in LotFrontage is :  0.0
# percenteage for null vals in LotArea is :  0.0
# percenteage for null vals in Street is :  0.0
# percenteage for null vals in Alley is :  0.0
# percenteage for null vals in LotShape is :  0.0
# percenteage for null vals in LandContour is :  0.0
# percenteage for null vals in Utilities is :  0.0
# percenteage for null vals in LotConfig is :  0.0
# percenteage for null vals in LandSlope is :  0.0
# percenteage for null vals in Neighborhood is :  0.0
# percenteage for null vals in Condition1 is :  0.0
# percenteage for null vals in Condition2 is :  0.0
# percenteage for null vals in BldgType is :  0.0
# percenteage for null vals in HouseStyle is :  0.0
# percenteage for null vals in OverallQual is :  0.0
# percenteage for null vals in OverallCond is :  0.0
# ...

# %% [markdown]
# #### Types of missing vals
#
# 1. Missing vals completely at random (MCAR)
#
#         Ex: A survey respondent skips a question because they misread it.
#
# ###
#
# 2. NULL vals are actually dependent on other vals/ Random vals aren't completely missing
#
#         Ex: A survey respondent skips a question because they don't want to answer it.
#
# ###
#
# 3. Missing vals are dependent on the missing vals themselves
#
#         Ex: A survey respondent skips a question because they don't want to answer it, and the question is about their income.

# %%
def null_values(x):
    """
    args: x take the numerical or the categorical columns
    column_with_null_values : a dict is created to store the values in key value pairs 
    loop will run for each column get the sum of null values
    check the if condition; if it is true then only the column name with the percentage of null value is going 
    to be stored in dict.
    """
    column_with_null_values = {}
    for i in x:
        print(i)
        if (df[i].isna().sum()!=0):
            print(i)
            column_with_null_values[i] = round((df[i].isna().sum()/len(df))*100,2)
            
            
    return column_with_null_values
