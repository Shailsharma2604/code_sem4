# %%
import pandas as pd
import numpy as np

# %%
dict1={
    'name':['Amit','Rahul','Shail'],
    'Roll':[2034,3455,5435],
    'Bday':['21-05-2020','23-06-2020','18-04-2020']
}

# %%
d=pd.DataFrame(dict1)
d.to_csv('mysample.csv')
d
# Out:
#     name  Roll        Bday
# 0   Amit  2034  21-05-2020
# 1  Rahul  3455  23-06-2020
# 2  Shail  5435  18-04-2020

# %%
df=pd.read_csv('mysample.csv',index_col=0,parse_dates=['Bday'],na_values={'name':'Amit','Roll':4356,'Bday':'11-04-2021'})
df
# Out:
# C:\Users\shail sharma\AppData\Local\Temp\ipykernel_10788\2044865721.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df=pd.read_csv('mysample.csv',index_col=0,parse_dates=['Bday'],na_values={'name':'Amit','Roll':4356,'Bday':'11-04-2021'})
#     name  Roll       Bday
# 0    NaN  2034 2020-05-21
# 1  Rahul  3455 2020-06-23
# 2  Shail  5435 2020-04-18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      object
#  1   Roll    3 non-null      int64
#  2   Bday    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 96.0+ bytes

# %%
df
# Out:
#     name  Roll       Bday
# 0    NaN  2034 2020-05-21
# 1  Rahul  3455 2020-06-23
# 2  Shail  5435 2020-04-18

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\shail sharma\\.vscode\\CC++\\pandas\\practice\\ToyotaCorolla.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   FuelType   1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   MetColor   1436 non-null   int64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   int64
#  9   Weight     1436 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 112.3+ KB

# %%
df.head(15)
# Out:
#     Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  Weight
# 0   13500   23  46986   Diesel   90         1          0  2000      3    1165
# 1   13750   23  72937   Diesel   90         1          0  2000      3    1165
# 2   13950   24  41711   Diesel   90         1          0  2000      3    1165
# 3   14950   26  48000   Diesel   90         0          0  2000      3    1165
# 4   13750   30  38500   Diesel   90         0          0  2000      3    1170
# 5   12950   32  61000   Diesel   90         0          0  2000      3    1170
# 6   16900   27  94612   Diesel   90         1          0  2000      3    1245
# 7   18600   30  75889   Diesel   90         1          0  2000      3    1245
# 8   21500   27  19700   Petrol  192         0          0  1800      3    1185
# 9   12950   23  71138   Diesel   69         0          0  1900      3    1105
# 10  20950   25  31461   Petrol  192         0          0  1800      3    1185
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Book3.csv")
df[['event']]
# Out:
#    event
# 0   rain
# 1  cloud
# 2  clear
# 3   rain
# 4  cloud
# 5  clear
# 6  clear
# 7   rain
# 8   rain
# 9  cloud

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Book1.csv",parse_dates=['Date'])
df
# Out:
#           Date  Temp  Wind Weather      City
# 0   01-01-2023    45     8   clear  amritsar
# 1   02-01-2023    45     5   clear  amritsar
# 2   03-01-2023    45     2   clear  amritsar
# 3   04-01-2023    41     3   clear  amritsar
# 4   05-01-2023    41     4   clear  amritsar
# 5   06-01-2023    41     7    rain  amritsar
# 6   07-01-2023    41     9    rain     ajmer
# 7   08-01-2023    35     2    rain     ajmer
# 8   09-01-2023    35     3    rain     ajmer
# 9   10-01-2023    35     1    rain     ajmer
# 10  11-01-2023    35     2    rain     ajmer
# 11  12-01-2023    35     4    rain     ajmer
# 12  13-01-2023    35     8   sunny   rajpura
# 13  14-01-2023    30     9   sunny   rajpura
# 14  15-01-2023    30     5   sunny   rajpura
# 15  16-01-2023    30     6   sunny   rajpura
# 16  17-01-2023    30     2   sunny   rajpura
# 17  18-01-2023    20     1   sunny      agra
# 18  19-01-2023    20     4  cloudy      agra
# 19  20-01-2023    20     6  cloudy      agra

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     20 non-null     object
#  1   Temp     20 non-null     int64
#  2   Wind     20 non-null     int64
#  3   Weather  20 non-null     object
#  4   City     20 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 928.0+ bytes

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Book1.csv",na_values={'temp':'45'})
df.to_csv('new.csv',header=False)
df.isnull().sum()
# Out:
# Date       0
# Temp       0
# Wind       0
# Weather    0
# City       0
# dtype: int64

# %%
import pandas as pd
import numpy as np
df=pd.read_excel(".\\.\\Book4.xlsx",na_values={'date':'01-01-2023'},parse_dates=['date'])
df
# Out:
#    date  temp   wind weather
# 0   NaT     20     5   clear
# 1   NaT     21     7   clear
# 2   NaT     21     1   clear
# 3   NaT     21     8   clear
# 4   NaT     22     1   clear
# 5   NaT     22     2   cloud
# 6   NaT     22     5   cloud
# 7   NaT     22     7   cloud
# 8   NaT     22     9   cloud
# 9   NaT     20     8   cloud
# 10  NaT     19     2    rain
# 11  NaT     19     3    rain
# 12  NaT     19     5    rain
# 13  NaT     19     8    rain
# 14  NaT     20     2    rain
# 15  NaT     20     1    rain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     0 non-null      datetime64[ns]
#  1   temp     16 non-null     int64
#  2   wind     16 non-null     int64
#  3   weather  16 non-null     object
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 640.0+ bytes

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(".\\.\\book6.csv",na_values=[22])
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     16 non-null     object
#  1   temp     11 non-null     float64
#  2   wind     16 non-null     int64
#  3   weather  16 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 640.0+ bytes
#           date  temp   wind weather
# 0   01-01-2023   20.0     5   clear
# 1   02-01-2023   21.0     7   clear
# 2   03-01-2023   21.0     1   clear
# 3   04-01-2023   21.0     8   clear
# 4   05-01-2023    NaN     1   clear
# 5   06-01-2023    NaN     2   cloud
# 6   07-01-2023    NaN     5   cloud
# 7   08-01-2023    NaN     7   cloud
# 8   09-01-2023    NaN     9   cloud
# 9   10-01-2023   20.0     8   cloud
# 10  11-01-2023   19.0     2    rain
# 11  12-01-2023   19.0     3    rain
# 12  13-01-2023   19.0     5    rain
# 13  14-01-2023   19.0     8    rain
# ...

# %%
import pandas as pd

def convert_weather(c):
    if c=="1":
        return "this"
    return c



df=pd.read_csv("Book7.csv",converters={
    'wind' : convert_weather
})
df
# Out:
#           date  temp   wind weather
# 0   01-01-2023     20     5   clear
# 1   02-01-2023     21     7   clear
# 2   03-01-2023     21  this   clear
# 3   04-01-2023     21     8   clear
# 4   05-01-2023     22  this   clear
# 5   06-01-2023     22     2   cloud
# 6   07-01-2023     22     5   cloud
# 7   08-01-2023     22     7   cloud
# 8   09-01-2023     22     9   cloud
# 9   10-01-2023     20     8   cloud
# 10  11-01-2023     19     2    rain
# 11  12-01-2023     19     3    rain
# 12  13-01-2023     19     5    rain
# 13  14-01-2023     19     8    rain
# 14  15-01-2023     20     2    rain
# 15  16-01-2023     20  this    rain

# %%
import pandas as pd
def check(cell):
    if cell=="01-01-2023":
        return "this"
    return cell

df=pd.read_csv("C:\\Users\\shail sharma\\.vscode\\CC++\\pandas\\practice\\Book2.csv",converters={
    'date': check
})
df
# Out:
#    date\ttemp\twind\tweather
# 0   01-01-2023\t20\t5\tclear
# 1   02-01-2023\t21\t7\tclear
# 2   03-01-2023\t21\t1\tclear
# 3   04-01-2023\t21\t8\tclear
# 4   05-01-2023\t22\t2\tclear
# 5   06-01-2023\t22\t5\tcloud
# 6   07-01-2023\t22\t7\tcloud
# 7   08-01-2023\t22\t9\tcloud
# 8   09-01-2023\t22\t8\tcloud
# 9   10-01-2023\t22\t2\tcloud
# 10  11-01-2023\t19\t3\tcloud
# 11   12-01-2023\t19\t5\train
# 12   13-01-2023\t19\t8\train
# 13   14-01-2023\t19\t5\train
# 14   15-01-2023\t20\t2\train
# 15   16-01-2023\t20\t3\train

# %%
df=pd.read_csv("C:\\Users\\shail sharma\\.vscode\\CC++\\pandas\\practice\\Book1.csv",parse_dates=["Date"],na_values={'Temp':'35'})
df.set_index('Date',inplace=True)
df.isnull().sum()
# Out:
# Temp       6
# Wind       0
# Weather    0
# City       0
# dtype: int64

# %%
new_df=df.fillna('0')
new_df
# Out:
#             Temp  Wind Weather      City
# Date
# 01-01-2023  45.0     8   clear  amritsar
# 02-01-2023  45.0     5   clear  amritsar
# 03-01-2023  45.0     2   clear  amritsar
# 04-01-2023  41.0     3   clear  amritsar
# 05-01-2023  41.0     4   clear  amritsar
# 06-01-2023  41.0     7    rain  amritsar
# 07-01-2023  41.0     9    rain     ajmer
# 08-01-2023     0     2    rain     ajmer
# 09-01-2023     0     3    rain     ajmer
# 10-01-2023     0     1    rain     ajmer
# 11-01-2023     0     2    rain     ajmer
# 12-01-2023     0     4    rain     ajmer
# 13-01-2023     0     8   sunny   rajpura
# 14-01-2023  30.0     9   sunny   rajpura
# 15-01-2023  30.0     5   sunny   rajpura
# 16-01-2023  30.0     6   sunny   rajpura
# 17-01-2023  30.0     2   sunny   rajpura
# 18-01-2023  20.0     1   sunny      agra
# 19-01-2023  20.0     4  cloudy      agra
# 20-01-2023  20.0     6  cloudy      agra

# %%
new_df=df.fillna({
    'Temp':'0',
    'Wind':'1'
})
new_df
# Out:
#             Temp  Wind Weather      City
# Date
# 01-01-2023  45.0     8   clear  amritsar
# 02-01-2023  45.0     5   clear  amritsar
# 03-01-2023  45.0     2   clear  amritsar
# 04-01-2023  41.0     3   clear  amritsar
# 05-01-2023  41.0     4   clear  amritsar
# 06-01-2023  41.0     7    rain  amritsar
# 07-01-2023  41.0     9    rain     ajmer
# 08-01-2023     0     2    rain     ajmer
# 09-01-2023     0     3    rain     ajmer
# 10-01-2023     0     1    rain     ajmer
# 11-01-2023     0     2    rain     ajmer
# 12-01-2023     0     4    rain     ajmer
# 13-01-2023     0     8   sunny   rajpura
# 14-01-2023  30.0     9   sunny   rajpura
# 15-01-2023  30.0     5   sunny   rajpura
# 16-01-2023  30.0     6   sunny   rajpura
# 17-01-2023  30.0     2   sunny   rajpura
# 18-01-2023  20.0     1   sunny      agra
# 19-01-2023  20.0     4  cloudy      agra
# 20-01-2023  20.0     6  cloudy      agra

# %% [markdown]
# Data Wrandling
# or
# Data Munging

# %%
df=pd.read_csv("C:\\Users\\shail sharma\\.vscode\\CC++\\pandas\\practice\\Book1.csv",parse_dates=["Date"],na_values={'Temp':'35'})
df.set_index('Date',inplace=True)
df.isnull().sum()
# Out:
# Temp       6
# Wind       0
# Weather    0
# City       0
# dtype: int64

# %%
df=pd.read_csv("C:\\Users\\shail sharma\\.vscode\\CC++\\pandas\\practice\\Book1.csv",parse_dates=["Date"],na_values={'Temp':'35'})
df.notnull().sum()
# Out:
# Date       20
# Temp       14
# Wind       20
# Weather    20
# City       20
# dtype: int64

# %%
df=pd.read_csv("Book1.csv ")
df
# Out:
#           Date  Temp  Wind Weather      City
# 0   01-01-2023    45     8   clear  amritsar
# 1   02-01-2023    45     5   clear  amritsar
# 2   03-01-2023    45     2   clear  amritsar
# 3   04-01-2023    41     3   clear  amritsar
# 4   05-01-2023    41     4   clear  amritsar
# 5   06-01-2023    41     7    rain  amritsar
# 6   07-01-2023    41     9    rain     ajmer
# 7   08-01-2023    35     2    rain     ajmer
# 8   09-01-2023    35     3    rain     ajmer
# 9   10-01-2023    35     1    rain     ajmer
# 10  11-01-2023    35     2    rain     ajmer
# 11  12-01-2023    35     4    rain     ajmer
# 12  13-01-2023    35     8   sunny   rajpura
# 13  14-01-2023    30     9   sunny   rajpura
# 14  15-01-2023    30     5   sunny   rajpura
# 15  16-01-2023    30     6   sunny   rajpura
# 16  17-01-2023    30     2   sunny   rajpura
# 17  18-01-2023    20     1   sunny      agra
# 18  19-01-2023    20     4  cloudy      agra
# 19  20-01-2023    20     6  cloudy      agra

# %% [markdown]
# fa
#
# 5 question numpy
#
# 5 quetsion from pandas
#
# 5 marks coding question*2

# %% [markdown]
# question hint :-
#
# x,y,z are col
#
# house no
#
# address
#
# city
#
# state

# %%
g= df.groupby('City')
g

# %%
for City,City_df in g:
    print(City)
    print(City_df)
# Out:
# agra
#           Date  Temp  Wind Weather  City
# 17  18-01-2023    20     1   sunny  agra
# 18  19-01-2023    20     4  cloudy  agra
# 19  20-01-2023    20     6  cloudy  agra
# ajmer
#           Date  Temp  Wind Weather   City
# 6   07-01-2023    41     9    rain  ajmer
# 7   08-01-2023    35     2    rain  ajmer
# 8   09-01-2023    35     3    rain  ajmer
# 9   10-01-2023    35     1    rain  ajmer
# 10  11-01-2023    35     2    rain  ajmer
# 11  12-01-2023    35     4    rain  ajmer
# amritsar
#          Date  Temp  Wind Weather      City
# 0  01-01-2023    45     8   clear  amritsar
# 1  02-01-2023    45     5   clear  amritsar
# 2  03-01-2023    45     2   clear  amritsar
# 3  04-01-2023    41     3   clear  amritsar
# 4  05-01-2023    41     4   clear  amritsar
# 5  06-01-2023    41     7    rain  amritsar
# rajpura
#           Date  Temp  Wind Weather     City
# 12  13-01-2023    35     8   sunny  rajpura
# 13  14-01-2023    30     9   sunny  rajpura
# ...

# %%
g.get_group(City)
# Out:
#           Date  Temp  Wind Weather     City
# 12  13-01-2023    35     8   sunny  rajpura
# 13  14-01-2023    30     9   sunny  rajpura
# 14  15-01-2023    30     5   sunny  rajpura
# 15  16-01-2023    30     6   sunny  rajpura
# 16  17-01-2023    30     2   sunny  rajpura

# %%
g.max()
# Out:
#                 Date  Temp  Wind Weather
# City
# agra      20-01-2023    20     6   sunny
# ajmer     12-01-2023    41     9    rain
# amritsar  06-01-2023    45     8    rain
# rajpura   17-01-2023    35     9   sunny

# %%
g.Temp.mean()
# Out:
# City
# agra        20.0
# ajmer       36.0
# amritsar    43.0
# rajpura     31.0
# Name: Temp, dtype: float64

# %%
g.describe()
# Out:
#           Temp                                                Wind            \
#          count  mean       std   min   25%   50%   75%   max count      mean
# City
# agra       3.0  20.0  0.000000  20.0  20.0  20.0  20.0  20.0   3.0  3.666667
# ajmer      6.0  36.0  2.449490  35.0  35.0  35.0  35.0  41.0   6.0  3.500000
# amritsar   6.0  43.0  2.190890  41.0  41.0  43.0  45.0  45.0   6.0  4.833333
# rajpura    5.0  31.0  2.236068  30.0  30.0  30.0  30.0  35.0   5.0  6.000000
#
#
#                std  min   25%  50%   75%  max
# City
# agra      2.516611  1.0  2.50  4.0  5.00  6.0
# ajmer     2.880972  1.0  2.00  2.5  3.75  9.0
# amritsar  2.316607  2.0  3.25  4.5  6.50  8.0
# rajpura   2.738613  2.0  5.00  6.0  8.00  9.0

# %%
# %matplotlib inline
g.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\shail sharma\.vscode\CC++\pandas\practice\1.ipynb Cell 33 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/shail%20sharma/.vscode/CC%2B%2B/pandas/practice/1.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().run_line_magic('matplotlib', 'inline')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shail%20sharma/.vscode/CC%2B%2B/pandas/practice/1.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> g.bar()
#
# File c:\Users\shail sharma\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:952, in GroupBy.__getattr__(self, attr)
#     949 if attr in self.obj:
#     950     return self[attr]
# --> 952 raise AttributeError(
#     953     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'bar'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     20 non-null     object
#  1   Temp     20 non-null     int64
#  2   Wind     20 non-null     int64
#  3   Weather  20 non-null     object
#  4   City     20 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 928.0+ bytes

# %%
a=dict1=pd.DataFrame({
    'name':['Amit','Rahul','Shail'],
    'Roll':[2034,3455,5435],
    'Bday':['21-05-2020','23-06-2020','18-04-2020']
})
a
# Out:
#     name  Roll        Bday
# 0   Amit  2034  21-05-2020
# 1  Rahul  3455  23-06-2020
# 2  Shail  5435  18-04-2020

# %%
b=dict1=pd.DataFrame({
    'name':['Amit','Rahul','Shail'],
    'Roll':[2034,3455,5435],
    'Bday':['21-05-2020','23-06-2020','18-04-2020']
})
b
# Out:
#     name  Roll        Bday
# 0   Amit  2034  21-05-2020
# 1  Rahul  3455  23-06-2020
# 2  Shail  5435  18-04-2020

# %%
new_df=pd.concat([a,b])
new_df
# Out:
#     name  Roll        Bday
# 0   Amit  2034  21-05-2020
# 1  Rahul  3455  23-06-2020
# 2  Shail  5435  18-04-2020
# 0   Amit  2034  21-05-2020
# 1  Rahul  3455  23-06-2020
# 2  Shail  5435  18-04-2020

# %%
new_df=pd.concat([a,b],ignore_index=True)
new_df
# Out:
#     name  Roll        Bday
# 0   Amit  2034  21-05-2020
# 1  Rahul  3455  23-06-2020
# 2  Shail  5435  18-04-2020
# 3   Amit  2034  21-05-2020
# 4  Rahul  3455  23-06-2020
# 5  Shail  5435  18-04-2020

# %%
pd.read_csv("https://www.kaggle.com/datasets/oddrationale/mnist-in-csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# c:\Users\shail sharma\.vscode\CC++\pandas\practice\1.ipynb Cell 39 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shail%20sharma/.vscode/CC%2B%2B/pandas/practice/1.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> pd.read_csv("https://www.kaggle.com/datasets/oddrationale/mnist-in-csv")
#
# ...

# %%
import pandas as pd
import requests

url = "https://github.com/cs109/2014_data/blob/master/countries.csv"
s = requests.get(url).content
c = pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shail sharma\.vscode\CC++\pandas\practice\1.ipynb Cell 40 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/shail%20sharma/.vscode/CC%2B%2B/pandas/practice/1.ipynb#X54sZmlsZQ%3D%3D?line=3'>4</a> url = "https://github.com/cs109/2014_data/blob/master/countries.csv"
#       <a href='vscode-notebook-cell:/c%3A/Users/shail%20sharma/.vscode/CC%2B%2B/pandas/practice/1.ipynb#X54sZmlsZQ%3D%3D?line=4'>5</a> s = requests.get(url).content
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shail%20sharma/.vscode/CC%2B%2B/pandas/practice/1.ipynb#X54sZmlsZQ%3D%3D?line=5'>6</a> c = pd.read_csv()
#
# TypeError: read_csv() missing 1 required positional argument: 'filepath_or_buffer'

# %%
import pandas as pd
c=pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")
c
# Out:
#         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# ...      ...       ...       ...   ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008     Iyana  0.000128  girl
# 257997  2008    Kenley  0.000127  girl
# 257998  2008    Sloane  0.000127  girl
# 257999  2008   Elianna  0.000127  girl
#
# [258000 rows x 4 columns]

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258000 entries, 0 to 257999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   year     258000 non-null  int64
#  1   name     258000 non-null  object
#  2   percent  258000 non-null  float64
#  3   sex      258000 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 7.9+ MB

# %%
d=c.head(15)
d
# Out:
#     year     name   percent  sex
# 0   1880     John  0.081541  boy
# 1   1880  William  0.080511  boy
# 2   1880    James  0.050057  boy
# 3   1880  Charles  0.045167  boy
# 4   1880   George  0.043292  boy
# 5   1880    Frank  0.027380  boy
# 6   1880   Joseph  0.022229  boy
# 7   1880   Thomas  0.021401  boy
# 8   1880    Henry  0.020641  boy
# 9   1880   Robert  0.020404  boy
# 10  1880   Edward  0.019965  boy
# 11  1880    Harry  0.018175  boy
# 12  1880   Walter  0.014822  boy
# 13  1880   Arthur  0.013504  boy
# 14  1880     Fred  0.013251  boy

# %%
def function(x):
    if(x=='boy'):
        print('this')
    return x
    
df=pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv",converters={
    'sex' : function
})
df
# Out:
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# this
# ...

# %%
new = {"Address": ['Chitkara, HP, Me','Chitkara, Rajpura, U']}
df = pd.DataFrame(new)
df[['Place', 'Area', 'Pep']] = df['Address'].str.split(",", expand = True)
new1 = df.drop('Address', axis=1)
new1
# Out:
#       Place      Area  Pep
# 0  Chitkara        HP   Me
# 1  Chitkara   Rajpura    U

# %% [markdown]
# Most improtant
#
#
#
#
# boolean indexing
