# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# # 1st Method

# %%
plt.plot()
# Out:
# []

# %%
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %% [markdown]
# # 2nd Method

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %% [markdown]
# # 3rd Method

# %%
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250])
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Anatomy of a Maplotlib Plot

# %% [markdown]
# ![3qlufjwpwlrr6tnlz0v0.png](attachment:3qlufjwpwlrr6tnlz0v0.png)

# %% [markdown]
# # Matplotlib Example Workflow

# %% [markdown]
# ## 1. Import matplotlib and get it ready for plotting in Jupyter

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Prepare Data

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %% [markdown]
# ## 3. Setup plot

# %%
fig,ax=plt.subplots(figsize=(5,5))

# %% [markdown]
# ## 4. Plot Data

# %%
ax.plot(x,y)

# %% [markdown]
# ## 5. Customize Plot

# %%
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")
# Out:
# [Text(0.5, 1.0, 'Simple Plot'),
#  Text(0.5, 4.444444444444445, 'x-axis'),
#  Text(4.4444444444444375, 0.5, 'y-axis')]

# %% [markdown]
# ## 6. Save a show (you save the valve whole figure)

# %%
fig.savefig("./image./sample-plot.png")

# %% [markdown]
# ## 7. Together

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[11,22,33,44]

fig,ax=plt.subplots(figsize=(5,5))

ax.plot(x,y)

ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")

fig.savefig("./image./sample-plot.png")

# %% [markdown]
# # Making figures with Numpy arrays

# %% [markdown]
# ## We want:

# %% [markdown]
# ### * Line Plot
# ### * Scatter Plot
# ### * Bar Plot
# ### * Histogram
# ### * SubPlots

# %%
import numpy as np

# %% [markdown]
# # Line Plot

# %% [markdown]
# ## Create Some Data

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ## Plot The Data

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ## Used Same data to make a scatter

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %% [markdown]
# ## Another scatter plot

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %% [markdown]
# # Bar plot

# %% [markdown]
# ## Make a plot from dictionary

# %%
nut_butter_prices={"Almond butter":10,
                   "peanut butter":8,
                   "Cashew butter":12}

fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Shail's Nut Butter Store", 
       ylabel="Prices($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Two options for subplots

# %% [markdown]
# # Subplots option 1

# %% [markdown]
# ### Plot to each different axis
#
# #### ax1.bar(nut_butter_prices.keys(), nut_butter_prices.values());
# #### ax2.scatter(x, np.sin(x))
# #### ax3.plot(x, x/2)
# #### ax4.hist(np.random.rand(1000));

# %%
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows = 2,
                                            ncols= 2,
                                            figsize=(10,5))
# ax1.bar(nut_butter_prices.keys(), nut_butter_prices.values());
# ax2.scatter(x, np.sin(x))
# ax3.plot(x, x/2)
# ax4.hist(np.random.rand(1000));
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# # Subplots option 2

# %%
fig,ax=plt.subplots(nrows=2,
                    ncols=2,
                    figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # Plotting from Pandas DataFrames

# %%
import pandas as pd

# %% [markdown]
# ## Make a DataFrame

# %%
car_sales=pd.read_csv("51 - car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts=pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2024",periods=1000))
ts=ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price']=car_sales["Price"].str.replace('$','')
car_sales['Price']
# Out:
# 0     4,000.00
# 1     5,000.00
# 2     7,000.00
# 3    22,000.00
# 4     3,500.00
# 5     4,500.00
# 6     7,500.00
# 7     7,000.00
# 8     6,250.00
# 9     9,700.00
# Name: Price, dtype: object

# %% [markdown]
# ## Remove last two zeros

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales['Price']=car_sales['Price'].str[:-2]

# %%
car_sales['Price'] = car_sales['Price'].str.replace('.', '')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4   4,000
# 1   Honda    Red          87899      4   5,000
# 2  Toyota   Blue          32549      3   7,000
# 3     BMW  Black          11179      5  22,000
# 4  Nissan  White         213095      4   3,500
# 5  Toyota  Green          99213      4   4,500
# 6   Honda   Blue          45698      4   7,500
# 7   Honda   Blue          54738      4   7,000
# 8  Toyota  White          60000      4   6,250
# 9  Nissan  White          31600      4   9,700

# %%
car_sales['Price'] = car_sales['Price'].str.replace(',', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %% [markdown]
# # Let's plot the total sales

# %%
car_sales.plot(x="Sale Date",y="Total Sales");

# %% [markdown]
# ## Reassign price column to int

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %% [markdown]
# ## Plot scatter plot with price column as numeric

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind='scatter');

# %% [markdown]
# # Bar Graph

# %%
x=np.random.rand(10,4)
x
# Out:
# array([[0.20486334, 0.44674995, 0.05090707, 0.68374138],
#        [0.02216213, 0.18257948, 0.36663429, 0.4183333 ],
#        [0.21664762, 0.91944556, 0.58461567, 0.72265929],
#        [0.13677404, 0.3147268 , 0.17612865, 0.42271948],
#        [0.95641771, 0.5011531 , 0.0990575 , 0.63305261],
#        [0.54377308, 0.47288782, 0.73187086, 0.74558275],
#        [0.30842745, 0.46511593, 0.68773268, 0.447772  ],
#        [0.22847929, 0.24357885, 0.69915463, 0.63365478],
#        [0.33432658, 0.08479199, 0.25185971, 0.83653368],
#        [0.56317966, 0.95503426, 0.07535901, 0.53558397]])

# %% [markdown]
# ## Turn it into dataframe

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.204863  0.446750  0.050907  0.683741
# 1  0.022162  0.182579  0.366634  0.418333
# 2  0.216648  0.919446  0.584616  0.722659
# 3  0.136774  0.314727  0.176129  0.422719
# 4  0.956418  0.501153  0.099057  0.633053
# 5  0.543773  0.472888  0.731871  0.745583
# 6  0.308427  0.465116  0.687733  0.447772
# 7  0.228479  0.243579  0.699155  0.633655
# 8  0.334327  0.084792  0.251860  0.836534
# 9  0.563180  0.955034  0.075359  0.535584

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind = "bar")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind = "bar");

# %% [markdown]
# # Histograms

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist");
