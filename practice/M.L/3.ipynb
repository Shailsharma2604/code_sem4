# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# # 1st Method

# %%
plt.plot()
# Out:
# []

# %%
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %% [markdown]
# # 2nd Method

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %% [markdown]
# # 3rd Method

# %%
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250])

# %% [markdown]
# # 83
