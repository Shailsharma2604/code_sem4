# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot();

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# # 1st Method

# %%
plt.plot()
# Out:
# []

# %%
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %% [markdown]
# # 2nd Method

# %%
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %% [markdown]
# # 3rd Method

# %%
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250])
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Anatomy of a Maplotlib Plot

# %% [markdown]
# ![3qlufjwpwlrr6tnlz0v0.png](attachment:3qlufjwpwlrr6tnlz0v0.png)

# %% [markdown]
# # Matplotlib Example Workflow

# %% [markdown]
# ## 1. Import matplotlib and get it ready for plotting in Jupyter

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Prepare Data

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %% [markdown]
# ## 3. Setup plot

# %%
fig,ax=plt.subplots(figsize=(5,5))

# %% [markdown]
# ## 4. Plot Data

# %%
ax.plot(x,y)

# %% [markdown]
# ## 5. Customize Plot

# %%
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")
# Out:
# [Text(0.5, 1.0, 'Simple Plot'),
#  Text(0.5, 4.444444444444445, 'x-axis'),
#  Text(4.4444444444444375, 0.5, 'y-axis')]

# %% [markdown]
# ## 6. Save a show (you save the valve whole figure)

# %%
fig.savefig("./image./sample-plot.png")

# %% [markdown]
# ## 7. Together

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[11,22,33,44]

fig,ax=plt.subplots(figsize=(5,5))

ax.plot(x,y)

ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")

fig.savefig("./image./sample-plot.png")

# %% [markdown]
# # Making figures with Numpy arrays

# %% [markdown]
# ## We want:

# %% [markdown]
# ### * Line Plot
# ### * Scatter Plot
# ### * Bar Plot
# ### * Histogram
# ### * SubPlots

# %%
import numpy as np

# %% [markdown]
# # Line Plot

# %% [markdown]
# ## Create Some Data

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ## Plot The Data

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2);

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ## Used Same data to make a scatter

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %% [markdown]
# ## Another scatter plot

# %% [markdown]
# ![download.png](attachment:download.png)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %% [markdown]
# # Bar plot

# %% [markdown]
# ## Make a plot from dictionary

# %%
nut_butter_prices={"Almond butter":10,
                   "peanut butter":8,
                   "Cashew butter":12}

fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Shail's Nut Butter Store", 
       ylabel="Prices($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # Two options for subplots

# %% [markdown]
# # Subplots option 1

# %% [markdown]
# ### Plot to each different axis
#
# #### ax1.bar(nut_butter_prices.keys(), nut_butter_prices.values());
# #### ax2.scatter(x, np.sin(x))
# #### ax3.plot(x, x/2)
# #### ax4.hist(np.random.rand(1000));

# %%
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows = 2,
                                            ncols= 2,
                                            figsize=(10,5))
# ax1.bar(nut_butter_prices.keys(), nut_butter_prices.values());
# ax2.scatter(x, np.sin(x))
# ax3.plot(x, x/2)
# ax4.hist(np.random.rand(1000));
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# # Subplots option 2

# %%
fig,ax=plt.subplots(nrows=2,
                    ncols=2,
                    figsize=(10,5))
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # Plotting from Pandas DataFrames

# %%
import pandas as pd

# %% [markdown]
# ## Make a DataFrame

# %%
car_sales=pd.read_csv("51 - car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts=pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2024",periods=1000))
ts=ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price']=car_sales["Price"].str.replace('$','')
car_sales['Price']
# Out:
# 0     4,000.00
# 1     5,000.00
# 2     7,000.00
# 3    22,000.00
# 4     3,500.00
# 5     4,500.00
# 6     7,500.00
# 7     7,000.00
# 8     6,250.00
# 9     9,700.00
# Name: Price, dtype: object

# %% [markdown]
# ## Remove last two zeros

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
car_sales['Price']=car_sales['Price'].str[:-2]

# %%
car_sales['Price'] = car_sales['Price'].str.replace('.', '')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4   4,000
# 1   Honda    Red          87899      4   5,000
# 2  Toyota   Blue          32549      3   7,000
# 3     BMW  Black          11179      5  22,000
# 4  Nissan  White         213095      4   3,500
# 5  Toyota  Green          99213      4   4,500
# 6   Honda   Blue          45698      4   7,500
# 7   Honda   Blue          54738      4   7,000
# 8  Toyota  White          60000      4   6,250
# 9  Nissan  White          31600      4   9,700

# %%
car_sales['Price'] = car_sales['Price'].str.replace(',', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %% [markdown]
# # Let's plot the total sales

# %%
car_sales.plot(x="Sale Date",y="Total Sales");

# %% [markdown]
# ## Reassign price column to int

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %% [markdown]
# ## Plot scatter plot with price column as numeric

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind='scatter');

# %% [markdown]
# # Bar Graph

# %%
x=np.random.rand(10,4)
x
# Out:
# array([[0.37983587, 0.7730909 , 0.61286154, 0.31819303],
#        [0.55303944, 0.0142877 , 0.74814689, 0.9175733 ],
#        [0.13248157, 0.79435676, 0.50081602, 0.57014371],
#        [0.76953105, 0.75432118, 0.29309154, 0.69510886],
#        [0.45330554, 0.56211434, 0.77040686, 0.15463784],
#        [0.33187344, 0.71469204, 0.21617451, 0.24859319],
#        [0.43405336, 0.67381898, 0.78919494, 0.56347993],
#        [0.660506  , 0.67151181, 0.90698799, 0.00345148],
#        [0.94059775, 0.68746902, 0.39489313, 0.64638885],
#        [0.35043149, 0.76511096, 0.29257383, 0.10699377]])

# %% [markdown]
# ## Turn it into dataframe

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.379836  0.773091  0.612862  0.318193
# 1  0.553039  0.014288  0.748147  0.917573
# 2  0.132482  0.794357  0.500816  0.570144
# 3  0.769531  0.754321  0.293092  0.695109
# 4  0.453306  0.562114  0.770407  0.154638
# 5  0.331873  0.714692  0.216175  0.248593
# 6  0.434053  0.673819  0.789195  0.563480
# 7  0.660506  0.671512  0.906988  0.003451
# 8  0.940598  0.687469  0.394893  0.646389
# 9  0.350431  0.765111  0.292574  0.106994

# %%
df.plot.bar();

# %%
df.plot(kind='bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind = "bar")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind = "bar");

# %% [markdown]
# # Histograms

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=40);

# %% [markdown]
# # New data set

# %%
heart_disease=pd.read_csv("92 - heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## Histogram

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# # Which one should you use ?
# ## pyplot vs matplotlib OO method?

# %% [markdown]
# ### * When plotting something quickly, okay to use the pyplot method
# ### * When plotting something more advanced, use the OO method

# %% [markdown]
# # OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %% [markdown]
# ## Pyplot method

# %%
 over_50.plot(kind='scatter',
              x='age',
              y='chol',
              c='target');

# %%
 over_50.plot(kind='scatter',
              x='age',
              y='chol',
              c='target',
              figsize=(10,6));

# %% [markdown]
# ## OO method

# %%
fix,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

# %%
fix,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             ax=ax);

ax.set_xlim([45,100]);

# %% [markdown]
# # 94
